# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# %%
# Importing selenium webdriver 
from selenium import webdriver

# %%
# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
#Importing requests
import requests

# %%
# importing regex
import re

# %%
#Question 1

import warnings 
warnings.filterwarnings("ignore")

# Opening the browser
driver=webdriver.Chrome("C:\\Users\HP\Downloads\chromedriver_win32\chromedriver.exe") 
time.sleep(3)

# Opening the homepage of most viewd youtubes
url = "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"
driver.get(url)
time.sleep(2)

#clicking the table
table_click = driver.find_element_by_xpath("//*[@id='mw-content-text']/div[1]/table[3]/tbody")
table_click.click()

# %%
#30 time we scroll down by 10000 in order to generate more Comments
for _ in range(30):
    driver.execute_script("window.scrollBy(0,30)")

# %%
#make empty lists
Ranks = []
Names = []
Artists = []
Upload_date = []
Views = []


#scrape ranks
rk = driver.find_elements_by_xpath("//*[@id='mw-content-text']/div[1]/table[3]/tbody/tr[2]/td[1]")
for i in rk:
    if i.text is None:
        Ranks.append("--")
    else:
        Ranks.append(i.text)


# scrape name
nm = driver.find_elements_by_xpath("//*[@id='mw-content-text']/div[1]/table[3]/tbody/tr[2]/td[2]")
for i in nm:
    Names.append(i.text)
    
# scrape the artists
art = driver.find_elements_by_xpath("//*[@id='mw-content-text']/div[1]/table[3]/tbody/tr[2]/td[3]")
for i in art:
    Artists.append(i.text)
    
#scrape upload date
dt = driver.find_elements_by_xpath("//*[@id='mw-content-text']/div[1]/table[3]/tbody/tr[2]/td[5]")
for i in dt:
    Upload_date.append(i.text)

#scrape views
vw = driver.find_elements_by_xpath("//*[@id='mw-content-text']/div[1]/table[3]/tbody/tr[2]/td[4]")
for i in vw:
    Views.append(i.text)

# %%
#Question 2

import warnings 
warnings.filterwarnings("ignore")

# Opening the browser
driver=webdriver.Chrome("C:\\Users\HP\Downloads\chromedriver_win32\chromedriver.exe") 
time.sleep(3)

# Opening the homepage of most viewd youtubes
url = "https://www.bcci.tv/"
driver.get(url)
time.sleep(2)

# %%
#clicking for international fixtures
link_click = driver.find_element_by_xpath("//*[@id='navigation']/ul[1]/li[2]")
link_click.click()
time.sleep(10)

# %%
#make empty lists
match_title = []
series = []
place = []
date = []
Time_1 = []


#scrape match title
mt= driver.find_elements_by_xpath("//*[@class='fixture-card-mid d-flex align-items-center justify-content-between']")
for i in mt:
    if i.text is None:
        match_title.append("--")
    else:
        match_title.append(i.text)


# scrape series
sr = driver.find_elements_by_xpath("//*[@class='fix-text']")
for i in sr:
    series.append(i.text)
    
# scrape the place
plc = driver.find_elements_by_xpath("//*[@class='fix-place ng-binding ng-scope']")
for i in plc:
    place.append(i.text)
    
#scrape date
dt = driver.find_elements_by_xpath("//*[@class='match-card-left match-schedule']")
for i in dt:
    date.append(i.text)

#scrape time
tm = driver.find_elements_by_xpath("//*[@class='match-card-right match-schedule']")
for i in tm:
    Time_1.append(i.text)

# %%
#Question 3

import warnings 
warnings.filterwarnings("ignore")

# Opening the browser
driver=webdriver.Chrome("C:\\Users\HP\Downloads\chromedriver_win32\chromedriver.exe") 
time.sleep(3)

# Opening the homepage of exceptions
url = "https://www.guru99.com/"
driver.get(url)
time.sleep(2)

# %%
#10time we scroll down by 10000 in order to generate more Comments
for _ in range(10):
    driver.execute_script("window.scrollBy(0,10)")

# %%
#make empty lists
name = []
description = []

# scrape name
nm = driver.find_elements_by_xpath("//*[@class='p_ styleable-title']")
for i in nm:
    series.append(i.text)
    
# scrape description
dsc = driver.find_elements_by_xpath("//*[@class='p_ styleable-description']")
for i in dsc:
    place.append(i.text)

# %%
#Question 4

import warnings 
warnings.filterwarnings("ignore")

# Opening the browser
driver=webdriver.Chrome("C:\\Users\HP\Downloads\chromedriver_win32\chromedriver.exe") 
time.sleep(3)

# Opening the homepage of exceptions
url = "http://statisticstimes.com/"
driver.get(url)
time.sleep(2)

# %%
#make empty lists
ranks = []
state = []
GSDP= []
share = []
GDP = []


#scrape ranks
rk= driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[1]")
for i in rk:
    if i.text is None:
        match_title.append("--")
    else:
        match_title.append(i.text)


# scrape state
st = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[2]")
for i in st:
    series.append(i.text)
    
# scrape the GSDP
gs = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[4]")
for i in gs:
    GSDP.append(i.text)
    
# scrape the GSDP
gs = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[8]")
for i in gs:
    GSDP.append(i.text)
    
#scrape share
sh = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[5]")
for i in sh:
    share.append(i.text)

#scrape GDP
gd = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[6]")
for i in gd:
    GDP.append(i.text)

# %%
#Question five 

import warnings 
warnings.filterwarnings("ignore")

# Opening the browser
driver=webdriver.Chrome("C:\\Users\HP\Downloads\chromedriver_win32\chromedriver.exe") 
time.sleep(3)

# Opening the homepage of exceptions
url = "https://github.com/dsrscientist/IBM_HR_Attrition_Rate_Analytics"
driver.get(url)
time.sleep(2)

# %%
#make empty lists
repo_title = []
repo_descr = []
comment= []
language = []



#scrape repo title
rp= driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[1]")
for i in rp:
    if i.text is None:
        repo_title.append("--")
    else:
        repo_title.append(i.text)


# scrape repo descr
rd = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[2]")
for i in rd:
    repo_descr.append(i.text)
    
# scrape the comment
cm = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[4]")
for i in gcm:
    comment.append(i.text)
    
# scrape the language
lg = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[8]")
for i in lg:
    language.append(i.text)

# %%
#Question six

import warnings 
warnings.filterwarnings("ignore")

# Opening the browser
driver=webdriver.Chrome("C:\\Users\HP\Downloads\chromedriver_win32\chromedriver.exe") 
time.sleep(3)

# Opening the homepage of exceptions
url = "http://www.billboard.com/"
driver.get(url)
time.sleep(2)

# %%
#make empty lists
song = []
artist= []
rank= []
p_rank = []
week_board = []


#scrape song
sg= driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[1]")
for i in sg:
    if i.text is None:
        song.append("--")
    else:
        song.append(i.text)


# scrape artist
at = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[2]")
for i in at:
    artist.append(i.text)
    
# scrape the rank
rk = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[4]")
for i in rk:
    rank.append(i.text)
    
# scrape the p_rank
prk = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[8]")
for i in prk:
    p_rank.append(i.text)
    
#scrape week_board
wk = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[5]")
for i in wk:
    week_board.append(i.text)

# %%
#Question seven

import warnings 
warnings.filterwarnings("ignore")

# Opening the browser
driver=webdriver.Chrome("C:\\Users\HP\Downloads\chromedriver_win32\chromedriver.exe") 
time.sleep(3)

# Opening the homepage of exceptions
url = "https://www.naukri.com/"
driver.get(url)
time.sleep(2)

# %%
#make empty lists
name = []
designation = []
company= []
skill = []
location = []


#scrape name
nm= driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[1]")
for i in nm:
    if i.text is None:
        name.append("--")
    else:
        name.append(i.text)


# scrape designation
ds = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[2]")
for i in ds:
    designation.append(i.text)
    
# scrape the comapny
cp = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[4]")
for i in cp:
    company.append(i.text)
    
# scrape the skill
sk = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[8]")
for i in sk:
    skill.append(i.text)
    
#scrape location
lc = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[5]")
for i in lc:
    location.append(i.text)

# %%
#Question eight

import warnings 
warnings.filterwarnings("ignore")

# Opening the browser
driver=webdriver.Chrome("C:\\Users\HP\Downloads\chromedriver_win32\chromedriver.exe") 
time.sleep(3)

# Opening the homepage of exceptions
url = "https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/"
driver.get(url)
time.sleep(2)

# %%
#make empty lists
book = []
author = []
volumes= []
publisher = []
genre = []


#scrape book
bk= driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[1]")
for i in bk:
    if i.text is None:
        book.append("--")
    else:
        book.append(i.text)


# scrape author
au = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[2]")
for i in au:
    author.append(i.text)
    
# scrape the volumes
vl = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[4]")
for i in vl:
    volumes.append(i.text)
    
# scrape the publisher
pb = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[8]")
for i in pb:
    publisher.append(i.text)
    
#scrape genre
gn = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[5]")
for i in gn:
    genre.append(i.text)

# %%
#Question nine

import warnings 
warnings.filterwarnings("ignore")

# Opening the browser
driver=webdriver.Chrome("C:\\Users\HP\Downloads\chromedriver_win32\chromedriver.exe") 
time.sleep(3)

# Opening the homepage of exceptions
url = "https://www.imdb.com/list/ls095964455/"
driver.get(url)
time.sleep(2)

# %%
#make empty lists
name = []
year= []
genre = []
run_time = []
ratings =[]
votes=[]

#scrape name
nm= driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[1]")
for i in nm:
    if i.text is None:
        name.append("--")
    else:
        name.append(i.text)


# scrape year
yr = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[2]")
for i in yr:
    year.append(i.text)
    
# scrape the genre
gs = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[4]")
for i in gs:
    genre.append(i.text)
    
# scrape the run time
rt = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[8]")
for i in rt:
    run_time.append(i.text)
    
#scrape ratings
rg = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[5]")
for i in rg:
    ratings.append(i.text)

#scrape votes
vt = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[6]")
for i in vt:
    votes.append(i.text)

# %%
#Question ten 

import warnings 
warnings.filterwarnings("ignore")

# Opening the browser
driver=webdriver.Chrome("C:\\Users\HP\Downloads\chromedriver_win32\chromedriver.exe") 
time.sleep(3)

# Opening the homepage of exceptions
url = "https://archive.ics.uci.edu/"
driver.get(url)
time.sleep(2)

# %%
#make empty lists
dataset_name= []
dataset_type = []
task= []
attribute_type = []
no_of_instances = []
no_of_attriute=[]
year=[]

#scrape ds name
ds= driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[1]")
for i in ds:
    if i.text is None:
        dataset_name.append("--")
    else:
    dataset_name.append(i.text)


# scrape ds type
dt = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[2]")
for i in dt:
    dataset_type.append(i.text)
    
# scrape the task
tk = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[4]")
for i in tk:
    task.append(i.text)
    
# scrape the att type
at = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[8]")
for i in at:
    attribute_type.append(i.text)
    
#scrape no of instances
no = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[5]")
for i in no:
    no_of_instances.append(i.text)

#scrape no of att
att = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[6]")
for i in att:
    no_of_attribute.append(i.text)

#scrape no of year
yr = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[6]")
for i in yr:
    year.append(i.text)

# %%
#make empty lists
ranks = []
state = []
GSDP= []
share = []
GDP = []


#scrape ranks
rk= driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[1]")
for i in rk:
    if i.text is None:
        match_title.append("--")
    else:
        match_title.append(i.text)


# scrape state
st = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[2]")
for i in st:
    series.append(i.text)
    
# scrape the GSDP
gs = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[4]")
for i in gs:
    GSDP.append(i.text)
    
# scrape the GSDP
gs = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[8]")
for i in gs:
    GSDP.append(i.text)
    
#scrape share
sh = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[5]")
for i in sh:
    share.append(i.text)

#scrape GDP
gd = driver.find_elements_by_xpath("//*[@id='table_id']/tbody/tr[1]/td[6]")
for i in gd:
    GDP.append(i.text)
