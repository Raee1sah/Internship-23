# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_test=pd.read_csv(r"C:\\Users\HP\Downloads\Project-Housing--2---1-\Project-Housing_splitted\test.csv")
df_train=pd.read_csv(r"C:\\Users\HP\Downloads\Project-Housing--2---1-\Project-Housing_splitted\train.csv")

# %%
df_train
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     127         120       RL          NaN     4928   Pave   NaN      IR1
# 1     889          20       RL         95.0    15865   Pave   NaN      IR1
# 2     793          60       RL         92.0     9920   Pave   NaN      IR1
# 3     110          20       RL        105.0    11751   Pave   NaN      IR1
# 4     422          20       RL          NaN    16635   Pave   NaN      IR1
# ...   ...         ...      ...          ...      ...    ...   ...      ...
# 1163  289          20       RL          NaN     9819   Pave   NaN      IR1
# 1164  554          20       RL         67.0     8777   Pave   NaN      Reg
# 1165  196         160       RL         24.0     2280   Pave   NaN      Reg
# 1166   31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 1167  617          60       RL          NaN     7861   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1163         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1164         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1165         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1166         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1167         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2007        WD         Normal     128000
# 1        10   2007        WD         Normal     268000
# 2         6   2007        WD         Normal     269790
# 3         1   2010       COD         Normal     190000
# 4         6   2009        WD         Normal     215000
# ...     ...    ...       ...            ...        ...
# 1163      2   2010        WD         Normal     122000
# 1164      5   2009        WD         Normal     108000
# 1165      7   2009        WD         Normal     148500
# 1166      7   2008        WD         Normal      40000
# 1167      6   2006        WD         Normal     183200
#
# [1168 rows x 81 columns]

# %%
df_test
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     337          20       RL         86.0    14157   Pave   NaN      IR1
# 1    1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2     929          20       RL          NaN    11838   Pave   NaN      Reg
# 3    1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4    1227          60       RL         86.0    14598   Pave   NaN      IR1
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 287    83          20       RL         78.0    10206   Pave   NaN      Reg
# 288  1048          20       RL         57.0     9245   Pave   NaN      IR2
# 289    17          20       RL          NaN    11241   Pave   NaN      IR1
# 290   523          50       RM         50.0     5000   Pave   NaN      Reg
# 291  1379         160       RM         21.0     1953   Pave   NaN      Reg
#
#     LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0           HLS    AllPub  ...           0        0    NaN   NaN         NaN
# 1           Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 2           Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 3           Bnk    AllPub  ...           0        0    NaN   NaN         NaN
# 4           Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# ..          ...       ...  ...         ...      ...    ...   ...         ...
# 287         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 288         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 289         Lvl    AllPub  ...           0        0    NaN   NaN        Shed
# 290         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 291         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#     MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0         0      7    2007        WD         Normal
# 1         0      8    2009       COD        Abnorml
# 2         0      6    2009        WD         Normal
# 3         0      7    2009        WD         Normal
# 4         0      1    2008        WD         Normal
# ..      ...    ...     ...       ...            ...
# 287       0     10    2008        WD         Normal
# 288       0      2    2008        WD         Normal
# 289     700      3    2010        WD         Normal
# 290       0     10    2006        WD         Normal
# 291       0      6    2006        WD         Normal
#
# [292 rows x 80 columns]

# %%
df_train.shape
# Out:
# (1168, 81)

# %%
df_test.shape
# Out:
# (292, 80)

# %%
df_train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1168.000000  1168.000000    954.00000    1168.000000  1168.000000
# mean    724.136130    56.767979     70.98847   10484.749144     6.104452
# std     416.159877    41.940650     24.82875    8957.442311     1.390153
# min       1.000000    20.000000     21.00000    1300.000000     1.000000
# 25%     360.500000    20.000000     60.00000    7621.500000     5.000000
# 50%     714.500000    50.000000     70.00000    9522.500000     6.000000
# 75%    1079.500000    70.000000     80.00000   11515.500000     7.000000
# max    1460.000000   190.000000    313.00000  164660.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1168.000000  1168.000000   1168.000000  1161.000000  1168.000000  ...
# mean      5.595890  1970.930651   1984.758562   102.310078   444.726027  ...
# std       1.124343    30.145255     20.785185   182.595606   462.664785  ...
# min       1.000000  1875.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1966.000000     0.000000     0.000000  ...
# 50%       5.000000  1972.000000   1993.000000     0.000000   385.500000  ...
# 75%       6.000000  2000.000000   2004.000000   160.000000   714.500000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1168.000000  1168.000000    1168.000000  1168.000000  1168.000000
# mean     96.206336    46.559932      23.015411     3.639555    15.051370
# std     126.158988    66.381023      63.191089    29.088867    55.080816
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    24.000000       0.000000     0.000000     0.000000
# 75%     171.000000    70.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1168.000000   1168.000000  1168.000000  1168.000000    1168.000000
# mean      3.448630     47.315068     6.344178  2007.804795  181477.005993
# std      44.896939    543.264432     2.686352     1.329738   79105.586863
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  130375.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163995.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  215000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
df_train.isnull().all()
# Out:
# Id               False
# MSSubClass       False
# MSZoning         False
# LotFrontage      False
# LotArea          False
#                  ...
# MoSold           False
# YrSold           False
# SaleType         False
# SaleCondition    False
# SalePrice        False
# Length: 81, dtype: bool

# %%
df_train.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      214
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
#heatmap for null values 
sns.heatmap(df_train.isnull())
plt.title("Null values")
plt.show()

# %%
df_train.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
df_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1168 non-null   int64
#  1   MSSubClass     1168 non-null   int64
#  2   MSZoning       1168 non-null   object
#  3   LotFrontage    954 non-null    float64
#  4   LotArea        1168 non-null   int64
#  5   Street         1168 non-null   object
#  6   Alley          77 non-null     object
#  7   LotShape       1168 non-null   object
#  8   LandContour    1168 non-null   object
#  9   Utilities      1168 non-null   object
#  10  LotConfig      1168 non-null   object
#  11  LandSlope      1168 non-null   object
#  12  Neighborhood   1168 non-null   object
#  13  Condition1     1168 non-null   object
#  14  Condition2     1168 non-null   object
#  15  BldgType       1168 non-null   object
#  16  HouseStyle     1168 non-null   object
#  17  OverallQual    1168 non-null   int64
#  18  OverallCond    1168 non-null   int64
#  19  YearBuilt      1168 non-null   int64
#  20  YearRemodAdd   1168 non-null   int64
#  21  RoofStyle      1168 non-null   object
#  22  RoofMatl       1168 non-null   object
#  23  Exterior1st    1168 non-null   object
#  24  Exterior2nd    1168 non-null   object
#  25  MasVnrType     1161 non-null   object
#  26  MasVnrArea     1161 non-null   float64
#  27  ExterQual      1168 non-null   object
#  28  ExterCond      1168 non-null   object
#  29  Foundation     1168 non-null   object
#  30  BsmtQual       1138 non-null   object
#  31  BsmtCond       1138 non-null   object
#  32  BsmtExposure   1137 non-null   object
#  33  BsmtFinType1   1138 non-null   object
#  34  BsmtFinSF1     1168 non-null   int64
#  35  BsmtFinType2   1137 non-null   object
#  36  BsmtFinSF2     1168 non-null   int64
#  37  BsmtUnfSF      1168 non-null   int64
#  38  TotalBsmtSF    1168 non-null   int64
#  39  Heating        1168 non-null   object
#  40  HeatingQC      1168 non-null   object
#  41  CentralAir     1168 non-null   object
#  42  Electrical     1168 non-null   object
#  43  1stFlrSF       1168 non-null   int64
#  44  2ndFlrSF       1168 non-null   int64
#  45  LowQualFinSF   1168 non-null   int64
#  46  GrLivArea      1168 non-null   int64
#  47  BsmtFullBath   1168 non-null   int64
#  48  BsmtHalfBath   1168 non-null   int64
#  49  FullBath       1168 non-null   int64
#  50  HalfBath       1168 non-null   int64
#  51  BedroomAbvGr   1168 non-null   int64
#  52  KitchenAbvGr   1168 non-null   int64
#  53  KitchenQual    1168 non-null   object
#  54  TotRmsAbvGrd   1168 non-null   int64
#  55  Functional     1168 non-null   object
#  56  Fireplaces     1168 non-null   int64
#  57  FireplaceQu    617 non-null    object
#  58  GarageType     1104 non-null   object
#  59  GarageYrBlt    1104 non-null   float64
#  60  GarageFinish   1104 non-null   object
#  61  GarageCars     1168 non-null   int64
#  62  GarageArea     1168 non-null   int64
#  63  GarageQual     1104 non-null   object
#  64  GarageCond     1104 non-null   object
#  65  PavedDrive     1168 non-null   object
#  66  WoodDeckSF     1168 non-null   int64
#  67  OpenPorchSF    1168 non-null   int64
#  68  EnclosedPorch  1168 non-null   int64
#  69  3SsnPorch      1168 non-null   int64
#  70  ScreenPorch    1168 non-null   int64
#  71  PoolArea       1168 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          237 non-null    object
#  74  MiscFeature    44 non-null     object
#  75  MiscVal        1168 non-null   int64
#  76  MoSold         1168 non-null   int64
#  77  YrSold         1168 non-null   int64
#  78  SaleType       1168 non-null   object
#  79  SaleCondition  1168 non-null   object
#  80  SalePrice      1168 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 739.2+ KB

# %%
#joining the two together . The train and testing dataset
df_train['source']='train'
df_test['source']='test'
df=pd.concat([df_train,df_test],ignore_index=True)

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0      127         120       RL          NaN     4928   Pave   NaN      IR1
# 1      889          20       RL         95.0    15865   Pave   NaN      IR1
# 2      793          60       RL         92.0     9920   Pave   NaN      IR1
# 3      110          20       RL        105.0    11751   Pave   NaN      IR1
# 4      422          20       RL          NaN    16635   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455    83          20       RL         78.0    10206   Pave   NaN      Reg
# 1456  1048          20       RL         57.0     9245   Pave   NaN      IR2
# 1457    17          20       RL          NaN    11241   Pave   NaN      IR1
# 1458   523          50       RM         50.0     5000   Pave   NaN      Reg
# 1459  1379         160       RM         21.0     1953   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolQC  Fence MiscFeature MiscVal MoSold  \
# 0            Lvl    AllPub  ...    NaN    NaN         NaN       0      2
# 1            Lvl    AllPub  ...    NaN    NaN         NaN       0     10
# 2            Lvl    AllPub  ...    NaN    NaN         NaN       0      6
# 3            Lvl    AllPub  ...    NaN  MnPrv         NaN       0      1
# 4            Lvl    AllPub  ...    NaN    NaN         NaN       0      6
# ...          ...       ...  ...    ...    ...         ...     ...    ...
# 1455         Lvl    AllPub  ...    NaN    NaN         NaN       0     10
# 1456         Lvl    AllPub  ...    NaN    NaN         NaN       0      2
# 1457         Lvl    AllPub  ...    NaN    NaN        Shed     700      3
# 1458         Lvl    AllPub  ...    NaN    NaN         NaN       0     10
# 1459         Lvl    AllPub  ...    NaN    NaN         NaN       0      6
#
#      YrSold SaleType  SaleCondition  SalePrice  source
# 0      2007       WD         Normal   128000.0   train
# 1      2007       WD         Normal   268000.0   train
# 2      2007       WD         Normal   269790.0   train
# 3      2010      COD         Normal   190000.0   train
# 4      2009       WD         Normal   215000.0   train
# ...     ...      ...            ...        ...     ...
# 1455   2008       WD         Normal        NaN    test
# 1456   2008       WD         Normal        NaN    test
# 1457   2010       WD         Normal        NaN    test
# 1458   2006       WD         Normal        NaN    test
# 1459   2006       WD         Normal        NaN    test
#
# [1460 rows x 82 columns]

# %%
df.shape
# Out:
# (1460, 82)

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice', 'source'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 82 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1168 non-null   float64
#  81  source         1460 non-null   object
# dtypes: float64(4), int64(34), object(44)
# memory usage: 935.4+ KB

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice        float64
# source            object
# Length: 82, dtype: object

# %%
#changing non int to int 
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        print(i)
        df[i]=le.fit_transform(df[i])
# Out:
# MSZoning
# Street
# Alley
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition1
# Condition2
# BldgType
# HouseStyle
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# ExterQual
# ExterCond
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# Heating
# HeatingQC
# CentralAir
# Electrical
# KitchenQual
# Functional
# FireplaceQu
# GarageType
# GarageFinish
# GarageQual
# GarageCond
# PavedDrive
# PoolQC
# Fence
# MiscFeature
# SaleType
# SaleCondition
# source

# %%
df
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0      127         120         3          NaN     4928       1      2
# 1      889          20         3         95.0    15865       1      2
# 2      793          60         3         92.0     9920       1      2
# 3      110          20         3        105.0    11751       1      2
# 4      422          20         3          NaN    16635       1      2
# ...    ...         ...       ...          ...      ...     ...    ...
# 1455    83          20         3         78.0    10206       1      2
# 1456  1048          20         3         57.0     9245       1      2
# 1457    17          20         3          NaN    11241       1      2
# 1458   523          50         4         50.0     5000       1      2
# 1459  1379         160         4         21.0     1953       1      2
#
#       LotShape  LandContour  Utilities  ...  PoolQC  Fence  MiscFeature  \
# 0            0            3          0  ...       3      4            4
# 1            0            3          0  ...       3      4            4
# 2            0            3          0  ...       3      4            4
# 3            0            3          0  ...       3      2            4
# 4            0            3          0  ...       3      4            4
# ...        ...          ...        ...  ...     ...    ...          ...
# 1455         3            3          0  ...       3      4            4
# 1456         1            3          0  ...       3      4            4
# 1457         0            3          0  ...       3      4            2
# 1458         3            3          0  ...       3      4            4
# 1459         3            3          0  ...       3      4            4
#
#       MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice  source
# 0           0       2    2007         8              4   128000.0       1
# 1           0      10    2007         8              4   268000.0       1
# 2           0       6    2007         8              4   269790.0       1
# 3           0       1    2010         0              4   190000.0       1
# 4           0       6    2009         8              4   215000.0       1
# ...       ...     ...     ...       ...            ...        ...     ...
# 1455        0      10    2008         8              4        NaN       0
# 1456        0       2    2008         8              4        NaN       0
# 1457      700       3    2010         8              4        NaN       0
# 1458        0      10    2006         8              4        NaN       0
# 1459        0       6    2006         8              4        NaN       0
#
# [1460 rows x 82 columns]

# %%
df.isnull().all()
# Out:
# Id               False
# MSSubClass       False
# MSZoning         False
# LotFrontage      False
# LotArea          False
#                  ...
# YrSold           False
# SaleType         False
# SaleCondition    False
# SalePrice        False
# source           False
# Length: 82, dtype: bool

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice        292
# source             0
# Length: 82, dtype: int64

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# SalePrice      292
# LotFrontage    259
# GarageYrBlt     81
# MasVnrArea       8
# Id               0
#               ...
# ExterQual        0
# MasVnrType       0
# Exterior2nd      0
# Exterior1st      0
# source           0
# Length: 82, dtype: int64

# %%
col=df.columns

# %%
#a heatmap for null values 
sns.heatmap(df.isnull())
plt.title("Null values")
plt.show()

# %%
#checking for skewness
df.skew()
# Out:
# Id                0.000000
# MSSubClass        1.407657
# MSZoning         -1.735395
# LotFrontage       2.163569
# LotArea          12.207688
#                    ...
# YrSold            0.096269
# SaleType         -3.868638
# SaleCondition    -2.741167
# SalePrice         1.953878
# source           -1.501543
# Length: 82, dtype: float64

# %%
df.describe()
# Out:
#                 Id   MSSubClass     MSZoning  LotFrontage        LotArea  \
# count  1460.000000  1460.000000  1460.000000  1201.000000    1460.000000
# mean    730.500000    56.897260     3.028767    70.049958   10516.828082
# std     421.610009    42.300571     0.632017    24.284752    9981.264932
# min       1.000000    20.000000     0.000000    21.000000    1300.000000
# 25%     365.750000    20.000000     3.000000    59.000000    7553.500000
# 50%     730.500000    50.000000     3.000000    69.000000    9478.500000
# 75%    1095.250000    70.000000     3.000000    80.000000   11601.500000
# max    1460.000000   190.000000     4.000000   313.000000  215245.000000
#
#             Street        Alley     LotShape  LandContour    Utilities  ...  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean      0.995890     1.903425     1.942466     2.777397     0.000685  ...
# std       0.063996     0.394776     1.409156     0.707666     0.026171  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       1.000000     2.000000     0.000000     3.000000     0.000000  ...
# 50%       1.000000     2.000000     3.000000     3.000000     0.000000  ...
# 75%       1.000000     2.000000     3.000000     3.000000     0.000000  ...
# max       1.000000     2.000000     3.000000     3.000000     1.000000  ...
#
#             PoolQC        Fence  MiscFeature       MiscVal       MoSold  \
# count  1460.000000  1460.000000  1460.000000   1460.000000  1460.000000
# mean      2.991096     3.504795     3.922603     43.489041     6.321918
# std       0.140703     1.082912     0.404103    496.123024     2.703626
# min       0.000000     0.000000     0.000000      0.000000     1.000000
# 25%       3.000000     4.000000     4.000000      0.000000     5.000000
# 50%       3.000000     4.000000     4.000000      0.000000     6.000000
# 75%       3.000000     4.000000     4.000000      0.000000     8.000000
# max       3.000000     4.000000     4.000000  15500.000000    12.000000
#
#             YrSold     SaleType  SaleCondition      SalePrice       source
# count  1460.000000  1460.000000    1460.000000    1168.000000  1460.000000
# mean   2007.815753     7.513014       3.770548  181477.005993     0.800000
# std       1.328095     1.552100       1.100854   79105.586863     0.400137
# min    2006.000000     0.000000       0.000000   34900.000000     0.000000
# 25%    2007.000000     8.000000       4.000000  130375.000000     1.000000
# 50%    2008.000000     8.000000       4.000000  163995.000000     1.000000
# 75%    2009.000000     8.000000       4.000000  215000.000000     1.000000
# max    2010.000000     8.000000       5.000000  755000.000000     1.000000
#
# [8 rows x 82 columns]

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice', 'source'],
#       dtype='object')

# %%
#dealing with null values
df['LotFrontage'].fillna(df['LotFrontage'].mode()[0],inplace=True)
df['Alley'].fillna(df['Alley'].mode()[0],inplace=True)
df['MasVnrType'].fillna(df['MasVnrType'].mode()[0],inplace=True)
df['MasVnrArea'].fillna(df['MasVnrArea'].mode()[0],inplace=True)
df['BsmtQual'].fillna(df['BsmtQual'].mode()[0],inplace=True)
df['BsmtCond'].fillna(df['BsmtCond'].mode()[0],inplace=True)
df['BsmtExposure'].fillna(df['BsmtExposure'].mode()[0],inplace=True)
df['BsmtFinType1'].fillna(df['BsmtFinType1'].mode()[0],inplace=True)
df['BsmtFinSF1'].fillna(df['BsmtFinSF1'].mode()[0],inplace=True)
df['BsmtFinType2'].fillna(df['BsmtFinType2'].mode()[0],inplace=True)
df['Electrical'].fillna(df['Electrical'].mode()[0],inplace=True)
df['FireplaceQu'].fillna(df['FireplaceQu'].mode()[0],inplace=True)
df['GarageType'].fillna(df['GarageType'].mode()[0],inplace=True)
df['GarageYrBlt'].fillna(df['GarageYrBlt'].mode()[0],inplace=True)
df['GarageFinish'].fillna(df['GarageFinish'].mode()[0],inplace=True)
df['GarageQual'].fillna(df['GarageQual'].mode()[0],inplace=True)
df['GarageCond'].fillna(df['GarageCond'].mode()[0],inplace=True)
df['SalePrice'].fillna(df['SalePrice'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# source           0
# Length: 82, dtype: int64

# %%
#a heatmap for null values 
sns.heatmap(df.isnull())
plt.title("Null values")
plt.show()

# %% [markdown]
# Now, we longer have null values . We have a clean data set.

# %%
df.corr()
# Out:
#                      Id  MSSubClass  MSZoning  LotFrontage   LotArea  \
# Id             1.000000    0.011156 -0.006096    -0.012497 -0.033226
# MSSubClass     0.011156    1.000000  0.035900    -0.349116 -0.139781
# MSZoning      -0.006096    0.035900  1.000000    -0.101150 -0.034452
# LotFrontage   -0.012497   -0.349116 -0.101150     1.000000  0.281283
# LotArea       -0.033226   -0.139781 -0.034452     0.281283  1.000000
# ...                 ...         ...       ...          ...       ...
# YrSold         0.000712   -0.021407 -0.020628     0.003021 -0.014261
# SaleType       0.019773    0.012464  0.097437    -0.035773  0.012292
# SaleCondition -0.005806   -0.024940  0.009494     0.061393  0.034169
# SalePrice     -0.027436   -0.053864 -0.127094     0.298563  0.193490
# source        -0.030199   -0.006115 -0.047700     0.063364 -0.006430
#
#                  Street     Alley  LotShape  LandContour  Utilities  ...  \
# Id             0.008916 -0.001530  0.032122    -0.019659   0.013324  ...
# MSSubClass    -0.024969 -0.105995  0.119289    -0.002940  -0.022844  ...
# MSZoning       0.087654 -0.052039  0.061887    -0.017854  -0.001192  ...
# LotFrontage   -0.037078  0.118171 -0.085906    -0.078725  -0.009684  ...
# LotArea       -0.197131  0.060105 -0.165315    -0.149083   0.010123  ...
# ...                 ...       ...       ...          ...        ...  ...
# YrSold        -0.025043  0.020944  0.036449     0.020507   0.023353  ...
# SaleType       0.014339  0.008205 -0.000911    -0.025754  -0.126770  ...
# SaleCondition  0.006064  0.035717 -0.038118     0.033809  -0.089701  ...
# SalePrice      0.040478  0.115855 -0.217895     0.026475  -0.011958  ...
# source         0.021413 -0.022563 -0.005835    -0.009682  -0.052360  ...
#
#                  PoolQC     Fence  MiscFeature   MiscVal    MoSold    YrSold  \
# Id            -0.033928 -0.000399     0.037057 -0.006242  0.021172  0.000712
# MSSubClass    -0.005221  0.086360     0.034859 -0.007683 -0.013585 -0.021407
# MSZoning       0.002882 -0.061289     0.000673  0.009293 -0.031496 -0.020628
# LotFrontage   -0.191642 -0.033148     0.005325 -0.012274  0.012785  0.003021
# LotArea       -0.065167  0.036031    -0.103544  0.038068  0.001205 -0.014261
# ...                 ...       ...          ...       ...       ...       ...
# YrSold         0.060904 -0.035366    -0.055962  0.004906 -0.145721  1.000000
# SaleType      -0.013592 -0.006154    -0.003311  0.015773 -0.047386 -0.002327
# SaleCondition  0.097425  0.100675     0.003192  0.013027  0.013320  0.003880
# SalePrice     -0.144566  0.116192     0.058039 -0.008939  0.066714 -0.043444
# source        -0.031652 -0.054729    -0.006782  0.015429  0.016473 -0.016509
#
#                SaleType  SaleCondition  SalePrice    source
# Id             0.019773      -0.005806  -0.027436 -0.030199
# MSSubClass     0.012464      -0.024940  -0.053864 -0.006115
# MSZoning       0.097437       0.009494  -0.127094 -0.047700
# LotFrontage   -0.035773       0.061393   0.298563  0.063364
# LotArea        0.012292       0.034169   0.193490 -0.006430
# ...                 ...            ...        ...       ...
# YrSold        -0.002327       0.003880  -0.043444 -0.016509
# SaleType       1.000000       0.184067  -0.060111 -0.060919
# SaleCondition  0.184067       1.000000   0.190787 -0.003112
# SalePrice     -0.060111       0.190787   1.000000  0.228386
# source        -0.060919      -0.003112   0.228386  1.000000
#
# [82 rows x 82 columns]

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning           int32
# LotFrontage      float64
# LotArea            int64
#                   ...
# YrSold             int64
# SaleType           int32
# SaleCondition      int32
# SalePrice        float64
# source             int32
# Length: 82, dtype: object

# %%
#correlation heatmap
plt.figure(figsize=(30,30))
sns.heatmap(df.corr(), annot=False,fmt="0.2f",linewidth=0.1,linecolor="black")
# Out:
# <AxesSubplot:>

# %%
import warnings
warnings.filterwarnings('ignore')

#checking for outliers
plt.figure(figsize=(20,10))
for o in enumerate(df):
    plt.subplot(8,5,o[0]+1)
    sns.boxplot(df[o[1]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8300/1376721988.py in <module>
#       5 plt.figure(figsize=(20,10))
#       6 for o in enumerate(df):
# ----> 7     plt.subplot(8,5,o[0]+1)
#       8     sns.boxplot(df[o[1]])
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1270
#    1271     # First, search for an existing subplot with a matching spec.
# -> 1272     key = SubplotSpec._from_subplot_args(fig, args)
#    1273
#    1274     for ax in fig.axes:
#
# ~\anaconda3\lib\site-packages\matplotlib\gridspec.py in _from_subplot_args(figure, args)
#     651                     num = int(num)
#     652                 if num < 1 or num > rows*cols:
# --> 653                     raise ValueError(
#     654                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#     655                 i = j = num
#
# ValueError: num must be 1 <= num <= 40, not 41

# %%
plt.figure(figsize=(22,7))
df.corr()['SalePrice'].sort_values(ascending=False).drop(['SalePrice']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=13)
plt.ylabel('column with target names',fontsize=14)
plt.title('CORRELATION',fontsize=18)
plt.show()

# %%
#creating a distplot for describe
for i in df.describe().columns:
    sns.displot(df[i].dropna())
    plt.title("displot")
    plt.show()

# %%
#dividing the data into features and label
x= df.drop('SalePrice',axis=1)
y=df['SalePrice']

# %%
#training the data 
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC
from sklearn.metrics import r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression

# %%
lr=LinearRegression()

for i in range(0,100):
    x_train,x_test,y_train,y_test,=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"At random state {i},the training accuracy is = {r2_score(y_train,pred_train)}")
    print(f"At random state {i},the testing accuracy is = {r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# At random state 0,the training accuracy is = 0.7000528628410652
# At random state 0,the testing accuracy is = 0.627869292133263
#
#
# At random state 1,the training accuracy is = 0.7088389765834152
# At random state 1,the testing accuracy is = 0.5147894994077601
#
#
# At random state 2,the training accuracy is = 0.7194928684715756
# At random state 2,the testing accuracy is = 0.5512659191683472
#
#
# At random state 3,the training accuracy is = 0.7160512467166713
# At random state 3,the testing accuracy is = 0.43658438372472763
#
#
# At random state 4,the training accuracy is = 0.7144704035354583
# At random state 4,the testing accuracy is = 0.5558015787206354
#
#
# At random state 5,the training accuracy is = 0.7019163677010491
# At random state 5,the testing accuracy is = 0.6475338350231836
#
#
# At random state 6,the training accuracy is = 0.7198242442546394
# At random state 6,the testing accuracy is = 0.5449884420902021
#
#
# At random state 7,the training accuracy is = 0.7132316271388248
# At random state 7,the testing accuracy is = 0.6058724978903387
#
#
# At random state 8,the training accuracy is = 0.7033337233999055
# At random state 8,the testing accuracy is = 0.5673452552794025
#
#
# At random state 9,the training accuracy is = 0.7153467887606342
# At random state 9,the testing accuracy is = 0.5423476359856776
#
#
# At random state 10,the training accuracy is = 0.7144241794118005
# At random state 10,the testing accuracy is = 0.5756243226992466
#
#
# At random state 11,the training accuracy is = 0.7215535357433799
# At random state 11,the testing accuracy is = 0.5102059527844722
#
#
# At random state 12,the training accuracy is = 0.6914299150826146
# At random state 12,the testing accuracy is = 0.6804812970419286
#
#
# At random state 13,the training accuracy is = 0.6976705932518072
# At random state 13,the testing accuracy is = 0.6754179617595928
#
#
# At random state 14,the training accuracy is = 0.7010579469303814
# At random state 14,the testing accuracy is = 0.6553534503506134
#
#
# At random state 15,the training accuracy is = 0.7236946475624049
# At random state 15,the testing accuracy is = 0.4977610201832148
#
#
# At random state 16,the training accuracy is = 0.695530838346237
# At random state 16,the testing accuracy is = 0.6442777330535903
#
#
# At random state 17,the training accuracy is = 0.7027460554697895
# At random state 17,the testing accuracy is = 0.5483748071397547
#
#
# At random state 18,the training accuracy is = 0.6888365331064129
# At random state 18,the testing accuracy is = 0.7155499686698484
#
#
# At random state 19,the training accuracy is = 0.7088245790936111
# At random state 19,the testing accuracy is = 0.619521598518068
#
#
# At random state 20,the training accuracy is = 0.6916591249997954
# At random state 20,the testing accuracy is = 0.663011080531561
#
#
# At random state 21,the training accuracy is = 0.6803018277052997
# At random state 21,the testing accuracy is = 0.7077781299231716
#
#
# At random state 22,the training accuracy is = 0.7034176836651791
# At random state 22,the testing accuracy is = 0.646999794193493
#
#
# At random state 23,the training accuracy is = 0.7085994978668397
# At random state 23,the testing accuracy is = 0.5648423585290774
#
#
# At random state 24,the training accuracy is = 0.6936297798463942
# At random state 24,the testing accuracy is = 0.680243111635154
#
#
# At random state 25,the training accuracy is = 0.6930766586960924
# At random state 25,the testing accuracy is = 0.6462035057236497
#
#
# At random state 26,the training accuracy is = 0.6972526327284383
# At random state 26,the testing accuracy is = 0.6617029420183765
#
#
# At random state 27,the training accuracy is = 0.6954707548641827
# At random state 27,the testing accuracy is = 0.6598765018806939
#
#
# At random state 28,the training accuracy is = 0.6967796424335603
# At random state 28,the testing accuracy is = 0.6507280418683368
#
#
# At random state 29,the training accuracy is = 0.7184849893882549
# At random state 29,the testing accuracy is = 0.5533689357178374
#
#
# At random state 30,the training accuracy is = 0.6955123889176199
# At random state 30,the testing accuracy is = 0.6547961493355436
#
#
# At random state 31,the training accuracy is = 0.7583719503636662
# At random state 31,the testing accuracy is = 0.4405054295234291
#
#
# At random state 32,the training accuracy is = 0.6820672505633376
# At random state 32,the testing accuracy is = 0.6848592811441879
#
#
# At random state 33,the training accuracy is = 0.708250810133957
# At random state 33,the testing accuracy is = 0.6208342930231273
#
#
# At random state 34,the training accuracy is = 0.7056488462984978
# At random state 34,the testing accuracy is = 0.5979877377907814
#
#
# At random state 35,the training accuracy is = 0.7136416896977789
# At random state 35,the testing accuracy is = 0.5387444130019374
#
#
# At random state 36,the training accuracy is = 0.6932986666521024
# At random state 36,the testing accuracy is = 0.6101009594607804
#
#
# At random state 37,the training accuracy is = 0.6982039315509156
# At random state 37,the testing accuracy is = 0.6679834475494534
#
#
# At random state 38,the training accuracy is = 0.6997331882046844
# At random state 38,the testing accuracy is = 0.6122505237102107
#
#
# At random state 39,the training accuracy is = 0.7100828823629971
# At random state 39,the testing accuracy is = 0.5948685288825275
#
#
# At random state 40,the training accuracy is = 0.7107404797158519
# At random state 40,the testing accuracy is = 0.5868290144152225
#
#
# At random state 41,the training accuracy is = 0.711630519000105
# At random state 41,the testing accuracy is = 0.5717004623676942
#
#
# At random state 42,the training accuracy is = 0.708600801300466
# At random state 42,the testing accuracy is = 0.6316559367810864
#
#
# At random state 43,the training accuracy is = 0.7103175983809558
# At random state 43,the testing accuracy is = 0.6207295632542768
#
#
# At random state 44,the training accuracy is = 0.6881993796573487
# At random state 44,the testing accuracy is = 0.6689523764646648
#
#
# At random state 45,the training accuracy is = 0.7542619168353406
# At random state 45,the testing accuracy is = 0.23296826338519117
#
#
# At random state 46,the training accuracy is = 0.7225479868953806
# At random state 46,the testing accuracy is = 0.46388401001736357
#
#
# At random state 47,the training accuracy is = 0.6850984528080016
# At random state 47,the testing accuracy is = 0.5937493568136084
#
#
# At random state 48,the training accuracy is = 0.6991250580482575
# At random state 48,the testing accuracy is = 0.6649266952954387
#
#
# At random state 49,the training accuracy is = 0.6993307211003642
# At random state 49,the testing accuracy is = 0.6696058434970082
#
#
# At random state 50,the training accuracy is = 0.6882722814440111
# At random state 50,the testing accuracy is = 0.7173628296996795
#
#
# At random state 51,the training accuracy is = 0.6929561867695069
# At random state 51,the testing accuracy is = 0.6993617887747511
#
#
# At random state 52,the training accuracy is = 0.7164454788224907
# At random state 52,the testing accuracy is = 0.5677732769453001
#
#
# At random state 53,the training accuracy is = 0.696164461968678
# At random state 53,the testing accuracy is = 0.6809878175408586
#
#
# At random state 54,the training accuracy is = 0.7116354938560436
# At random state 54,the testing accuracy is = 0.6139375321714304
#
#
# At random state 55,the training accuracy is = 0.699749225065706
# At random state 55,the testing accuracy is = 0.668583431937835
#
#
# At random state 56,the training accuracy is = 0.7051420145192147
# At random state 56,the testing accuracy is = 0.6113132327820401
#
#
# At random state 57,the training accuracy is = 0.6929339558963541
# At random state 57,the testing accuracy is = 0.6642608585479266
#
#
# At random state 58,the training accuracy is = 0.7185501290405792
# At random state 58,the testing accuracy is = 0.5517866778096451
#
#
# At random state 59,the training accuracy is = 0.6895776806325282
# At random state 59,the testing accuracy is = 0.7056327303435408
#
#
# At random state 60,the training accuracy is = 0.6822408650918467
# At random state 60,the testing accuracy is = 0.7006228802007436
#
#
# At random state 61,the training accuracy is = 0.7066977982857203
# At random state 61,the testing accuracy is = 0.6292249880971479
#
#
# At random state 62,the training accuracy is = 0.7090342980905143
# At random state 62,the testing accuracy is = 0.6193797344738161
#
#
# At random state 63,the training accuracy is = 0.698840483896377
# At random state 63,the testing accuracy is = 0.6417000565809914
#
#
# At random state 64,the training accuracy is = 0.7245336885497469
# At random state 64,the testing accuracy is = 0.43999849483009623
#
#
# At random state 65,the training accuracy is = 0.7097686614197132
# At random state 65,the testing accuracy is = 0.5856949318080574
#
#
# At random state 66,the training accuracy is = 0.6943878402367841
# At random state 66,the testing accuracy is = 0.6397986579110284
#
#
# At random state 67,the training accuracy is = 0.7184941531650579
# At random state 67,the testing accuracy is = 0.5644496274812885
#
#
# At random state 68,the training accuracy is = 0.7090332481921107
# At random state 68,the testing accuracy is = 0.5757353920475141
#
#
# At random state 69,the training accuracy is = 0.6979207801947835
# At random state 69,the testing accuracy is = 0.6717803778183649
#
#
# At random state 70,the training accuracy is = 0.6795491061603283
# At random state 70,the testing accuracy is = 0.721243307798531
#
#
# At random state 71,the training accuracy is = 0.7154519362442018
# At random state 71,the testing accuracy is = 0.5498602192851625
#
#
# At random state 72,the training accuracy is = 0.7081343679377872
# At random state 72,the testing accuracy is = 0.620841921473035
#
#
# At random state 73,the training accuracy is = 0.7556008966632478
# At random state 73,the testing accuracy is = 0.1428849008769355
#
#
# At random state 74,the training accuracy is = 0.6886663964111265
# At random state 74,the testing accuracy is = 0.7023255826560457
#
#
# At random state 75,the training accuracy is = 0.7141075256431118
# At random state 75,the testing accuracy is = 0.5625476809032309
#
#
# At random state 76,the training accuracy is = 0.7067752364018725
# At random state 76,the testing accuracy is = 0.4717511689959176
#
#
# At random state 77,the training accuracy is = 0.7270004911687546
# At random state 77,the testing accuracy is = 0.44154864289818885
#
#
# At random state 78,the training accuracy is = 0.7270677552025218
# At random state 78,the testing accuracy is = 0.4677781732243258
#
#
# At random state 79,the training accuracy is = 0.6943500360989632
# At random state 79,the testing accuracy is = 0.6857125898882922
#
#
# At random state 80,the training accuracy is = 0.7196024396784544
# At random state 80,the testing accuracy is = 0.5355113415888908
#
#
# At random state 81,the training accuracy is = 0.729777386325337
# At random state 81,the testing accuracy is = 0.5175957854475286
#
#
# At random state 82,the training accuracy is = 0.6977802674617998
# At random state 82,the testing accuracy is = 0.661276819994744
#
#
# At random state 83,the training accuracy is = 0.7034466609948151
# At random state 83,the testing accuracy is = 0.6192584885628873
#
#
# At random state 84,the training accuracy is = 0.6935018706562003
# At random state 84,the testing accuracy is = 0.6503704372303225
#
#
# At random state 85,the training accuracy is = 0.7006703169662183
# At random state 85,the testing accuracy is = 0.6568621660978919
#
#
# At random state 86,the training accuracy is = 0.7081984686149795
# At random state 86,the testing accuracy is = 0.577185399357929
#
#
# At random state 87,the training accuracy is = 0.7435247406569148
# At random state 87,the testing accuracy is = 0.2571575641569279
#
#
# At random state 88,the training accuracy is = 0.6864582444090463
# At random state 88,the testing accuracy is = 0.7251677906524132
#
#
# At random state 89,the training accuracy is = 0.6745324260220897
# At random state 89,the testing accuracy is = 0.7038438168333037
#
#
# At random state 90,the training accuracy is = 0.7065930552390901
# At random state 90,the testing accuracy is = 0.6208191030072656
#
#
# At random state 91,the training accuracy is = 0.7379253241198991
# At random state 91,the testing accuracy is = 0.25989559250171446
#
#
# At random state 92,the training accuracy is = 0.7096509687728829
# At random state 92,the testing accuracy is = 0.5125515040649297
#
#
# At random state 93,the training accuracy is = 0.7033449005623553
# At random state 93,the testing accuracy is = 0.6218063619834022
#
#
# At random state 94,the training accuracy is = 0.6961454042207806
# At random state 94,the testing accuracy is = 0.6370530293672173
#
#
# At random state 95,the training accuracy is = 0.7126612387011793
# At random state 95,the testing accuracy is = 0.5527418420468668
#
#
# At random state 96,the training accuracy is = 0.7095810547649851
# At random state 96,the testing accuracy is = 0.5834260838580874
#
#
# At random state 97,the training accuracy is = 0.7046424886768392
# At random state 97,the testing accuracy is = 0.6438297776614723
#
#
# At random state 98,the training accuracy is = 0.6865585122392016
# At random state 98,the testing accuracy is = 0.7125806283619798
#
#
# At random state 99,the training accuracy is = 0.7180840145235816
# At random state 99,the testing accuracy is = 0.37031754027017416

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=43)

# %%
pred_test=lr.predict(x_test)

# %%
pred_train=lr.predict(x_train)

# %%
print(r2_score(y_test,pred_test)*100)
# Out:
# 61.38680048722198

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression(normalize=True)
lr.fit(x_train,y_train)
# Out:
# LinearRegression(normalize=True)

# %%
pred_test=lr.predict(x_test)
pred_test
# Out:
# array([125918.31492133, 210888.31541376, 208727.04355068, 118919.4728356 ,
#        197941.51279855, 152694.48691333, 206395.67617684, 106488.3356978 ,
#         92515.97124996, 168424.35221902, 109069.6502197 , 310697.72625081,
#        104389.21816639, 193671.89128116, 145362.09131444, 129931.28220692,
#        220060.64407272, 282685.48402244, 210043.48675771, 156264.24530891,
#        185582.05803064, 356911.39760242, 190800.44177356, 111193.66569274,
#        217604.57347087, 131717.60001386, 157244.08767291, 149875.18051281,
#        155000.72960259, 164584.94768434, 107533.55498439, 193438.19107109,
#         77917.81778258, 234483.99857837, 147310.73850948, 223180.94744914,
#        209910.0872942 , 113482.43792833,  86723.18406918, 154156.65024858,
#        176460.59226831, 177093.65407368,  88414.58351985, 136859.65981206,
#         92313.41309039, 136387.1012241 , 180113.03577464, 120598.86575464,
#        117002.21977292, 211043.7419712 , 137099.42270327, 290179.92526109,
#        125633.96438214, 299640.72920915, 214348.08760967, 131970.69112237,
#        185397.09632814, 167476.47607643, 124434.32187217, 143891.70683703,
#        103586.58401697,  57349.67881186, 149220.84927342, 247977.98025336,
#        109372.51668154, 114078.56919307, 121538.53239108, 216372.61195675,
#        170149.87705015, 110638.84449334, 209517.19470581, 212190.08264939,
#        164408.41940639, 120817.04363589, 171738.96466542, 141189.78555669,
#        167774.30295488, 222312.97526294,  52173.6048628 , 247625.65652518,
#        363899.09905297, 145985.7041916 , 165785.98189684, 258720.90814781,
#        256317.14219335, 183349.4378233 , 126804.25876556, 189147.69908203,
#        215350.94097476, 319398.17469464, 196661.41884258, 186525.83947848,
#        139640.55068477,  91494.59107543, 130492.59393783, 276464.35889099,
#        232510.02109856, 127973.68035771, 187168.98373554,  77652.14128427,
#        132217.68083877, 208053.48178489, 154906.07505375, 134413.15779112,
#        176244.54555379,  94186.8902732 , 162547.63797075, 230800.52261022,
#        114190.06642861, 193011.22799905, 275841.12495319, 322390.65228253,
#        192930.92934793, 212690.81424886, 189509.98653675, 124274.24004179,
#        140137.74668426, 130082.66890727, 161967.96352623, 217246.58780262,
#        217655.56847659, 169315.04838751,  90747.24586161, 149977.45274069,
#        125232.4867604 , 106716.09036467, 105225.45393023, 130750.36963206,
#        154759.25027035, 111611.9638382 , 103437.83217219, 167336.83924874,
#        110085.18745125, 105673.14567469, 199156.26968537, 231206.3307659 ,
#        348383.21362667, 341176.50789323, 188932.8022454 , 255158.41778114,
#        150594.27497463, 140540.0107071 , 213970.12833054, 140693.7174032 ,
#         50153.83659104, 127253.78676705, 121126.17697067, 176154.82481121,
#        146272.00168043, 152057.52512472, 161362.54836273, 267810.59751869,
#        120799.17769572,  94520.60228808, 203832.48492191, 210524.94477414,
#        224141.95399098,  98892.97888796, 150073.85220965, 167082.92560845,
#        170568.01138745, 244640.62772621, 184133.58661363, 171959.84267112,
#        153678.12636927, 223287.51015218, 237922.02535985, 151068.13938011,
#        141333.99084792, 127181.03801935, 170978.61733784,  98454.72388346,
#        217664.7978482 , 243677.59876797, 191496.59745283, 318418.42511625,
#        141675.59864481, 193127.86314216, 114933.24360963, 167109.92742208,
#        154967.76315837, 166517.82164904, 175829.11206397, 278520.67466023,
#        279910.63914665, 168531.40151723, 192020.36977899, 232371.19930425,
#        172709.17932946, 182896.10992299, 276546.84844407, 194713.30260144,
#        134523.6672979 , 133249.89609355, 239552.53859521, 181307.59037494,
#        201225.95844841,  84590.54310571, 203804.6024827 , 161974.97639818,
#        106735.08840992, 263757.58671559, 111168.43593848, 227493.92378152,
#        283117.41223317, 302443.42966602, 162761.59685664, 217276.70263298,
#        232269.39291252, 369716.72972889, 112242.03227519, 146371.43272742,
#        155319.40245143, 174987.44284432, 133563.80641046, 138843.86291324,
#        120252.29734071, 152767.02885635, 200964.80665593, 156605.12391081,
#         73882.03427477, 214367.07388281, 122502.31257046, 137432.54347116,
#        140106.5751314 , 175633.36012311, 114073.59866586, 135181.84976353,
#        185545.90177025, 187352.04239654, 163839.8411758 , 110593.05217515,
#        123900.14065908,  90696.28064585, 155494.37531421, 141816.0705915 ,
#        121308.29824755, 179785.79230897, 165205.09330817, 152316.35654316,
#        192733.7202275 , 111460.07029228,  89674.20181697, 272751.99351162,
#        148251.5699981 , 142001.36710297, 165407.0459578 , 167719.20281601,
#        157960.57245984, 164767.5540717 , 141321.47357016, 146114.48038457,
#        239486.95784665, 119166.03352002, 214672.26499947, 207524.03179576,
#        166824.34588637, 149021.02622324, 127514.61861994, 495663.16235967,
#        180292.03576694, 147745.29209983, 317373.76732649, 257072.67169591,
#        138829.91269088, 180297.82941646,  80376.46728838, 137364.70874106,
#        114172.09541327, 176491.64298039,  96362.05293009, 200098.19596841,
#        137273.06307736, 286605.79136506, 102510.20623184, 192793.08352118,
#         99305.26737192, 145334.18066822, 230300.78603805, 153000.9997499 ,
#        217076.00357151, 174510.36657807, 176522.26485218, 139956.19908351,
#        268227.6674221 , 220636.66479995, 101072.36962977, 123732.1391187 ,
#        200004.47516502,  82042.39602658, 146090.40794755,  94991.29828008])

# %%
pred_train=lr.predict(x_train)
pred_train
# Out:
# array([114421.21913881, 138714.93139198, 235788.4419806 , ...,
#        134205.56272083, 177889.17160315,  97730.90354493])

# %%
lr_accuracy=round(lr.score(x_train,y_train)*100)
lr_accuracy
# Out:
# 71

# %%
from sklearn.tree import DecisionTreeRegressor
tree=DecisionTreeRegressor(max_depth=15, min_samples_leaf=2)
tree.fit(x_train,y_train)
tree_pred=tree.predict(x_test)
tree_pred
# Out:
# array([120750.        , 169500.        , 237166.66666667, 122666.66666667,
#        190753.07692308, 215000.        , 203800.        , 142500.        ,
#        129333.33333333, 183000.        , 111166.66666667, 272500.        ,
#         73500.        , 147000.        , 138750.        , 135100.        ,
#        218250.        , 199500.        , 217250.        , 151500.        ,
#        180500.        , 272500.        , 140000.        , 135976.5       ,
#        180162.5       , 126000.        , 140000.        , 135943.5       ,
#        157466.66666667, 134600.        , 111166.66666667, 188566.66666667,
#         94500.        , 216750.        , 143500.        , 189361.1875    ,
#        197666.66666667, 140000.        ,  81333.33333333, 156250.        ,
#        186000.        , 179250.        ,  84750.        , 143666.66666667,
#        140000.        , 135943.5       , 172250.        , 119861.28571429,
#        109084.66666667, 140000.        , 141250.        , 199500.        ,
#        121500.        , 374500.        , 265500.        , 132750.        ,
#        132000.        , 157500.        , 109000.        , 136500.        ,
#        140000.        , 140000.        , 182166.66666667, 140000.        ,
#        140000.        , 134600.        ,  78666.66666667, 140000.        ,
#        188566.66666667,  55500.        , 160100.        , 229500.        ,
#        160250.        , 121750.        , 179250.        , 102200.        ,
#        139625.        , 241800.        , 150666.66666667, 241800.        ,
#        750000.        , 140000.        , 140000.        , 307666.66666667,
#        235666.66666667, 141950.        , 108452.88888889, 212750.        ,
#        225840.        , 334098.        , 231833.33333333, 206125.        ,
#         73250.        , 140000.        ,  86875.        , 254500.        ,
#        252646.5       , 162500.        , 202133.33333333, 140000.        ,
#        128633.33333333, 237166.66666667, 140000.        , 150666.66666667,
#        218500.        ,  78666.66666667, 140000.        , 392250.        ,
#        109000.        , 174333.33333333, 140000.        , 140000.        ,
#        158750.        , 244666.66666667, 211950.        , 109000.        ,
#        153833.33333333,  87750.        , 140000.        , 231833.33333333,
#        203066.66666667, 140000.        , 140000.        ,  80000.        ,
#         86875.        , 125500.        , 163000.        , 101000.        ,
#        140000.        , 132000.        ,  78666.66666667, 133000.        ,
#         94500.        , 120500.        , 180162.5       , 140000.        ,
#        431577.        , 435000.        , 209900.        , 346321.5       ,
#        136500.        , 113833.33333333, 213750.        , 139000.        ,
#         60000.        , 139333.33333333, 123381.25      , 140000.        ,
#        152283.33333333, 135943.5       , 139625.        , 347762.        ,
#        160366.5       , 140000.        , 152000.        , 176950.        ,
#        244666.66666667, 124250.        , 141500.        , 145250.        ,
#        140000.        , 254500.        , 147000.        , 174333.33333333,
#        151500.        , 262000.        , 197333.33333333, 150750.        ,
#        131500.        , 109084.66666667, 182000.        , 126750.        ,
#        182000.        , 140000.        , 135976.5       , 309825.66666667,
#         94500.        , 213750.        , 108633.33333333, 156983.33333333,
#         89750.        , 166420.        , 185750.        , 288500.        ,
#        293266.66666667, 159950.        , 178700.        , 248800.        ,
#        140000.        , 199400.        , 274106.5       , 140000.        ,
#        140000.        , 150666.66666667, 288500.        , 156250.        ,
#        134633.33333333, 140000.        , 190753.07692308, 139625.        ,
#        140000.        , 344333.33333333, 128750.        , 245500.        ,
#        288500.        , 346321.5       , 152283.33333333, 274300.        ,
#        231833.33333333, 392250.        , 110625.        , 166420.        ,
#        163000.        , 178000.        , 176750.        , 140000.        ,
#         91250.        , 143250.        , 180250.        , 171333.33333333,
#        140000.        , 220000.        , 121732.        , 111000.        ,
#        101000.        , 179250.        , 107500.        , 128633.33333333,
#        189361.1875    , 187875.        , 140000.        , 140000.        ,
#        140000.        , 140000.        , 134633.33333333, 139333.33333333,
#        164950.        , 178700.        , 139625.        , 135100.        ,
#        190753.07692308, 110625.        , 118950.        , 301466.66666667,
#        136000.        , 134600.        , 178950.        , 141950.        ,
#        175000.        , 152500.        , 140000.        , 140000.        ,
#        232500.        , 139333.33333333, 189361.1875    , 244899.5       ,
#        170750.        , 150450.        , 140000.        , 435000.        ,
#        175000.        , 119861.28571429, 309825.66666667, 274300.        ,
#        140000.        , 190753.07692308, 113833.33333333, 143750.        ,
#        140000.        , 169500.        , 140000.        , 189361.1875    ,
#         55500.        , 334098.        , 140000.        , 231833.33333333,
#         87833.33333333, 159500.        , 140000.        , 161000.        ,
#        203800.        , 183000.        , 171333.33333333, 159500.        ,
#        435000.        , 140000.        , 104250.        , 174333.33333333,
#        189361.1875    , 140000.        , 119861.28571429,  80000.        ])

# %%
tree_accuracy=round(tree.score(x_train,y_train)*100)
tree_accuracy
# Out:
# 99

# %%
from sklearn.ensemble import RandomForestRegressor 
rf=RandomForestRegressor(n_estimators=400,max_depth=6,min_samples_leaf=2,n_jobs=4)
rf.fit(x_train,y_train)
rf.pred=rf.predict(x_test)

# %%
rf_accuracy=round(rf.score(x_train,y_train)*100)
rf_accuracy
# Out:
# 92

# %%
import xgboost
from xgboost import XGBRegressor

model=XGBRegressor(n_estimators=100,learning_rate=0.05)
model.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.05, max_delta_step=0,
#              max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([124511.78 , 171006.81 , 194858.75 , 119540.45 , 202991.14 ,
#        174032.11 , 205735.67 , 142877.69 , 136768.44 , 157538.3  ,
#        113107.53 , 395099.4  ,  81215.336, 173885.08 , 162518.86 ,
#        121078.836, 221257.89 , 329523.97 , 229916.16 , 136613.75 ,
#        164452.81 , 321162.16 , 148122.39 , 141155.75 , 189103.52 ,
#        129775.65 , 135894.62 , 148556.02 , 145945.5  , 153360.81 ,
#         90249.66 , 165016.38 ,  83134.87 , 240050.34 , 126818.49 ,
#        202254.7  , 192197.77 , 140961.77 , 100556.35 , 140523.2  ,
#        162516.34 , 159763.56 , 110461.336, 147354.69 , 135797.05 ,
#        137551.11 , 170411.56 , 117972.72 ,  96578.   , 151639.97 ,
#        158313.25 , 308724.88 , 133922.56 , 325894.44 , 323754.8  ,
#        136284.66 , 123143.87 , 151466.7  , 123903.36 , 136017.17 ,
#        136843.6  , 135319.34 , 164248.95 , 139613.84 , 127997.9  ,
#        122033.555,  94157.47 , 138353.08 , 169104.42 ,  88694.89 ,
#        190801.28 , 242082.38 , 160743.55 , 132514.84 , 162630.03 ,
#        112908.56 , 140684.05 , 244643.77 , 150375.11 , 237565.39 ,
#        561654.4  , 140763.08 , 143665.72 , 290122.56 , 270245.28 ,
#        188989.66 , 104881.6  , 200425.72 , 201876.81 , 308666.47 ,
#        195969.06 , 190422.36 , 116742.445, 138177.64 , 103937.7  ,
#        274084.1  , 250515.6  , 137501.84 , 212707.58 , 136337.39 ,
#        125986.195, 224827.94 , 141251.27 , 147923.92 , 186077.67 ,
#         77158.234, 142024.44 , 293156.97 , 126275.9  , 162289.97 ,
#        143660.6  , 164277.97 , 180914.62 , 228925.53 , 180060.47 ,
#        124222.19 , 136303.31 ,  92995.28 , 142036.84 , 203764.02 ,
#        209665.77 , 144651.28 , 135799.86 , 128077.43 , 119684.625,
#        122939.98 , 142663.62 , 107242.45 , 141136.16 , 123046.67 ,
#        104509.586, 153916.19 ,  95065.21 , 110786.92 , 185820.39 ,
#        148821.23 , 444293.1  , 409600.16 , 189361.78 , 274436.34 ,
#        129067.734, 121761.48 , 184172.52 , 138561.8  ,  61478.3  ,
#        137058.58 , 126420.34 , 143641.86 , 147265.67 , 157152.38 ,
#        139373.53 , 346602.47 , 130953.36 , 137974.64 , 171475.31 ,
#        190478.17 , 231635.53 ,  88390.445, 145521.45 , 165365.27 ,
#        139872.17 , 300356.88 , 167665.86 , 156674.22 , 133618.39 ,
#        228981.67 , 240471.31 , 169432.36 , 141837.25 ,  94402.734,
#        182390.58 , 132325.8  , 195594.4  , 141468.62 , 163514.95 ,
#        334066.94 , 116844.95 , 187507.94 , 117024.31 , 140267.   ,
#        136510.81 , 143507.69 , 192827.94 , 329023.88 , 311732.03 ,
#        169384.02 , 175404.33 , 263039.5  , 140960.44 , 181597.97 ,
#        298823.84 , 139513.7  , 140090.17 , 142123.11 , 259568.05 ,
#        154770.67 , 177381.06 , 128505.77 , 201615.44 , 139373.53 ,
#        128185.3  , 304002.4  ,  87155.71 , 237987.98 , 316652.44 ,
#        334487.72 , 143181.23 , 239965.58 , 236259.92 , 335244.34 ,
#        122403.72 , 161732.   , 148589.67 , 167946.08 , 131267.1  ,
#        140302.03 , 119775.555, 145321.17 , 182072.58 , 161026.75 ,
#        131799.11 , 219735.84 , 124514.67 , 126550.36 , 120886.586,
#        139425.64 , 144096.66 , 130989.01 , 187582.25 , 161513.61 ,
#        140023.62 , 139206.5  , 138277.17 , 118636.42 , 174192.86 ,
#        145383.81 , 133641.14 , 170207.31 , 143660.19 , 134048.45 ,
#        192047.19 , 111918.18 , 107855.58 , 352882.7  , 114139.516,
#        141059.58 , 168331.84 , 143411.62 , 159613.64 , 161544.3  ,
#        141222.83 , 130877.625, 258955.12 , 131560.36 , 209015.06 ,
#        197938.36 , 157739.56 , 142649.7  , 141217.61 , 556447.3  ,
#        160931.72 , 123778.69 , 356129.4  , 260813.53 , 138782.83 ,
#        181407.44 ,  94611.13 , 146782.3  , 142221.9  , 203831.81 ,
#        136141.42 , 191305.34 ,  96900.586, 371401.   , 140817.89 ,
#        196890.69 ,  91753.14 , 133024.7  , 140989.2  , 136690.   ,
#        192002.67 , 164369.9  , 178869.52 , 124889.63 , 318641.8  ,
#        140721.52 , 132310.25 , 139729.23 , 189280.45 , 136729.   ,
#        120093.48 , 113885.664], dtype=float32)

# %%
model.score(x_train,y_train)*100
# Out:
# 98.63795384355392

# %%
model_accuracy=round(model.score(x_train,y_train)*100)
model_accuracy
# Out:
# 99

# %%
#Cross validation  for desisiontree
scr=cross_val_score(tree,x,y,cv=5)
scr.mean()
print("Cross validation score of DecisionTreeRegression:",scr.mean())
# Out:
# Cross validation score of DecisionTreeRegression: 0.5822471523725408

# %%
#Cross validation  for xgboost
scr=cross_val_score(model,x,y,cv=5)
scr.mean()
print("Cross validation score of Xgboost:",scr.mean())
# Out:
# Cross validation score of Xgboost: 0.6535023620750717

# %%
#saving the model
import pickle 
filename='churn.pkl'
pickle.dump(tree,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('churn.pkl','rb'))
result=loaded_model.score(x_test,y_test)*100
result
# Out:
# 76.91243583310451

# %%
#creatig a new df
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],pred_train[:]],index=["Predicted","Original"])

# %%
conclusion
# Out:
#                     0              1              2              3     \
# Predicted  120750.000000  169500.000000  237166.666667  122666.666667
# Original   114421.219139  138714.931392  235788.441981  134231.108859
#
#                     4              5              6              7     \
# Predicted  190753.076923  215000.000000  203800.000000  142500.000000
# Original   157111.172802  189054.048079  156264.687503  161665.629322
#
#                     8              9     ...          1158           1159  \
# Predicted  129333.333333  183000.000000  ...           NaN            NaN
# Original   337530.563540  189206.335804  ...  87793.646555  229899.295833
#
#                     1160           1161           1162           1163  \
# Predicted            NaN            NaN            NaN            NaN
# Original   149054.749382  135686.425449  154124.133382  146736.777884
#
#                    1164           1165           1166          1167
# Predicted           NaN            NaN            NaN           NaN
# Original   100470.75911  134205.562721  177889.171603  97730.903545
#
# [2 rows x 1168 columns]
